# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Caminho do ChromeDriver
chromedriver_path = "/Users/gabrielassuncao/Desktop/chromedriver"
driver = webdriver.Chrome(executable_path=chromedriver_path)

# Acesse o site desejado
url = "https://www.investing.com/indices/us-spx-500-futures-historical-data?"
driver.get(url)

valores = []

# Localiza todos os elementos da tabela usando a classe
# elements = driver.find_elements(By.CSS_SELECTOR, ".datatable_cell__0y0eu.datatable_cell--align-end__fwomz.datatable_cell--up__Gt_ed, .datatable_cell__0y0eu.datatable_cell--align-end__fwomz.datatable_cell--down__Mn_gX")
elements = driver.find_elements(By.CSS_SELECTOR, ".datatable_cell__0y0eu")

# Itera sobre os elementos e extrai os valores
for element in elements:
    valores.append(element.text)

# Exibe os valores extraídos
for i, valor in enumerate(valores):
    print(f"Valor {i + 1}: {valor}")

# Fecha o navegador
driver.quit()
# Out:
# /var/folders/pd/sdy9gj0s2zxd8rff4f422zp00000gn/T/ipykernel_23059/1635213237.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chromedriver_path)
# Valor 1:
# Valor 2:
# Valor 3:
# Valor 4:
# Valor 5:
# Valor 6:
# Valor 7:
# Valor 8:
# Valor 9:
# Valor 10:
# Valor 11:
# Valor 12:
# Valor 13:
# Valor 14:
# Valor 15:
# Valor 16:
# Valor 17:
# Valor 18:
# Valor 19:
# Valor 20:
# Valor 21:
# Valor 22:
# Valor 23:
# Valor 24:
# Valor 25:
# Valor 26: Date
# Valor 27: Price
# Valor 28: Open
# Valor 29: High
# Valor 30: Low
# Valor 31: Vol.
# Valor 32: Change %
# Valor 33: 04/13/2023
# Valor 34: 4,172.00
# Valor 35: 4,111.25
# Valor 36: 4,176.75
# Valor 37: 4,111.25
# Valor 38: 1.33M
# Valor 39: +1.29%
# Valor 40: 04/12/2023
# Valor 41: 4,119.00
# Valor 42: 4,137.50
# Valor 43: 4,177.75
# Valor 44: 4,113.50
# Valor 45: 15.04K
# Valor 46: -0.42%
# Valor 47: 04/11/2023
# Valor 48: 4,136.50
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Caminho do ChromeDriver
chromedriver_path = "/Users/gabrielassuncao/Desktop/chromedriver"
driver = webdriver.Chrome(executable_path=chromedriver_path)

# Acesse o site desejado
url = "https://www.profinance.ru/chart/sp500f/?s=SP500_FUT&hist=true&p=U1A1MDBfRlVUIzIjMSM3MjAjMzcwIzExIzAjMg=="  
driver.get(url)

# Crie uma lista para armazenar os valores
valores = []

# Localiza todos os elementos da tabela usando a classe
elements = driver.find_elements(By.CSS_SELECTOR, ".datatable_cell__0y0eu.datatable_cell--align-end__fwomz.datatable_cell--up__Gt_ed, .datatable_cell__0y0eu.datatable_cell--align-end__fwomz.datatable_cell--down__Mn_gX")
# elements = driver.find_elements(By.CSS_SELECTOR, ".datatable_cell__0y0eu")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# Caminho do ChromeDriver
chromedriver_path = "/Users/gabrielassuncao/Desktop/chromedriver"
driver = webdriver.Chrome(executable_path=chromedriver_path)

# Acesse o site desejado
url = "https://www.profinance.ru/chart/sp500f/?s=SP500_FUT&hist=true&p=U1A1MDBfRlVUIzIjMSM3MjAjMzcwIzExIzAjMg=="  
driver.get(url)

# Crie uma lista para armazenar os valores
valores = []

